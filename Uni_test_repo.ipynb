# %% [markdown]
# <a href="https://colab.research.google.com/github/Data-Science-Apprentices/cb-test-repo/blob/main/Uni_test_repo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

data = "https://github.com/Data-Science-Apprentices/cb-test-repo/raw/main/test_data_galaxies_1.pkl"

df = pd.read_pickle(data)
df.tail()
# Out:
#         StellarMass       SFR  Metallicity       Age    H2mass    Position
# 151370     8.970772 -1.862825     6.865888  9.733810  7.450675  251.175797
# 151371     8.324137 -1.874912     7.278814  9.814536  7.181321  228.499481
# 151372     8.187030 -2.450842     7.724004  9.964604  6.600506  246.989075
# 151373     8.256580 -1.851628     7.058324  9.673517  7.315062  242.138794
# 151374     8.395709 -1.619801     7.141418  9.641215  7.537473  220.469330
